# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)


import numpy as np
import matplotlib.pyplot as plt
# Out:
# TensorFlow version: 2.8.2

# %%
#Hyperparameter
learning_rate = 0.001
training_epochs = 10
batch_size = 100

# %%
#Dataset processing
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
#Data normalization
x_train, x_test = x_train/ 255.0, x_test/ 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
#Build model (use tf model sequential)

model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(256, activation=tf.nn.relu),
  tf.keras.layers.Dense(10),
  tf.keras.layers.Softmax()
])

model(tf.keras.Input(shape=(28, 28, 1)))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 256)               200960
#
#  dense_1 (Dense)             (None, 10)                2570
#
#  softmax (Softmax)           (None, 10)                0
#
# =================================================================
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Model compile & fit

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

model.fit(x_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2235 - accuracy: 0.9359
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0928 - accuracy: 0.9717
# Epoch 3/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0605 - accuracy: 0.9819
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0441 - accuracy: 0.9864
# Epoch 5/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0330 - accuracy: 0.9898
# Epoch 6/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0252 - accuracy: 0.9920
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0193 - accuracy: 0.9940
# Epoch 8/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0170 - accuracy: 0.9947
# Epoch 9/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0126 - accuracy: 0.9960
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0110 - accuracy: 0.9963

# %%
#Evaluation model

model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0846 - accuracy: 0.9788
# [0.08464819937944412, 0.9787999987602234]
